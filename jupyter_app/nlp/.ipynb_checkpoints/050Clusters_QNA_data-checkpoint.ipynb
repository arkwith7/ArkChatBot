# %% [markdown]
# # 군집화

# %% [markdown]
# ## 기본 개념
# 군집화(clustering), 또는 군집 분석(cluster analysis)이란 주어진 객체들을 같은 그룹에 속한 객체들은 최대한 유사하도록(또는 관련이 있도록), 그리고 다른 그룹에 속한 속한 객체들은 최대한 유사하지 않도록(또는 관련이 없도록) 그룹화하는 절차이다.

# %% [markdown]
# ## 활용
# * 이해
#     - 브라우징을 위해 연관된 문서들을 군집화한다.
#     - 유사 기능을 갖는 유전자 혹은 단백질을 군집화한다.
#     - 유사한 가격 변화를 보이는 주식들을 군집화한다.
# * 요약
#     - 넓은 지역의 강수량 분포를 군집화한다.
#
# ## 종류
# * 분할 군집화(partitional clustering): 데이터 객체들을 원소가 겹치지 않는 부분 집합으로 나눈다. 비계층적 군집화라고도 부른다.
# * 계층적 군집화(hierarchical clustering): 계층적 트리에 의해 구성되며 하위 군집을 상위 군집이 포함한다.

# %% [markdown]
# # 문서 군집

# %% [markdown]
# ## 문서 군집이란?
# 문서 군집(document clustering)이란 다수의 문서로 구성된 문서 집합의 문서들을 속성이 유사한 문서들끼리 집단(군집)화하는 절차를 말한다. 이때 **문서의 속성**과 **문서의 유사성**을 어떻게 정의할지가 매우 중요하다. 문서의 속성에는 군집의 목표에 따라 문서의 길이 등 다양한 정보를 반영할 수 있는데 앞서 살펴본 어휘 벡터 모델을 이용하는 것이 보통이다. 문서의 유사성은 벡터 간의 유사도 측정에 의하여 판단한다. 물론 군집을 어떠한 방법으로 만들 것인가도 중요하며 군집은 몇 개까지 만드는 것이 적절한지도 판단을 필요로 한다.
#
# 문서 군집은 다양하게 응용될 수 있다. 다수의 개별 문서가 포함된 대규모 문서 집합의 속성을 파악하기 힘들 때에 문서 군집을 이용하면 주어진 문서 집합의 개략적인 속성을 요약적으로 이해할 수 있다. 또한 검색 엔진에서 검색 결과를 서비스 이용자에게 돌려줄 때에 비슷한 문서들끼리 묶어서 표시함으로써 검색 결과의 유용성을 증대시킬 수도 있다.
#
# 한편 기계 학습의 관점에서 볼 때에 문서 군집은 비지도 학습(unsupervised learning)이다. 학습 자료가 주어지지 않은 상태에서 결과를 얻기 때문이다. 이는 다음 강의에서 다룰 문서 분류(document classification)와 대비되는 것이다. 경우에 따라 문서 군집은 지도 학습(supervised learning)인 문서 분류의 사전 준비 작업을 위해 이용되기도 한다.
#
# ## 계층적 군집화
# 계층적 군집화(hierarchicnal clustering)는 개별 자료 항목 하나 하나를 클러스터로 설정한 다음 클러스터 간의 유사성을 판단하여 유사한 클러스터들끼리 합병 동작을 모든 클러스터들이 하나의 클러스로 합쳐질 때까지 반복 수행하는 상향식(bottom up) 방식의 군집 방식이다.
#
# 계층적 군집화에는 자료 간의 거리, 혹은 유사도를 측정하는 방법, 거리를 최적화하는 방법, 군집 간의 연결(linkage)을 만드는 방법 등에 따라 여러 가지 기법이 존재한다.
#
# 다음은 자료 항목간의 거리를 유클리드 거리로 정의하고 군집 간의 거리는 두 군집에 속한 속성들의 값이 평균으로부터 떨어진 정도인 편차 제곱을 모두 합하여 구하는 워드(ward) 기법을 사용하는 계층적 군집화의 사례이다.
# 군집 분석 대상 문서 집합은 노무현 전직 대통령의 연설문으로 구성하였다.
# 연설문은 총 780건이다.

# %%
# 소요리문답 자료를 군집화 한다

import sys
import ujson
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
import matplotlib
from matplotlib import pyplot as plt


FEATURE_POSES = ["NNG", "NNP", "NR", "NP", "XR", "MAG", "VA", "VV"]
MA_KEYS = ["question_ma", "answer_ma"]


def read_documents(input_file_name):
    """주어진 이름의 파일에서 문서들을 읽어서 돌려준다."""
    
    documents = []

    with open(input_file_name, "r", encoding="utf-8") as input_file:
        for line in input_file:
            morphs = []
            json_obj = ujson.loads(line)

            for ma_key in MA_KEYS:
                for morph_lex, morph_cat in json_obj[ma_key]:
                    if morph_cat not in FEATURE_POSES:
                        continue
                        
                    morphs.append(morph_lex)

            document = " ".join(morphs)
            print(document)
            documents.append(document)

    return documents



def check_ma_keys(json_obj):
    """JSON 객체에 형태소 분석 키가 존재하는지 검사한다."""
    
    for ma_key in MA_KEYS:
        if ma_key not in json_obj or not json_obj[ma_key]:
            return False
        
    return True

def set_font():
    """차트의 글꼴을 설정한다."""
    
    if sys.platform in ["win32", "win64"]:
        font_name = "malgun gothic"
    elif sys.platform == "darwin":
        font_name = "AppleGothic"
        
    matplotlib.rc("font", family=font_name)
    

def read_president_fields(input_file_name):
    """주어진 이름의 파일에서 소요리문답 번호와 질문을 읽어서 돌려준다."""
    
    president_fields = []

    with open(input_file_name, "r", encoding="utf-8") as input_file:
        for line in input_file:
            json_obj = ujson.loads(line)
            president = json_obj["no"]
            aa = "[" + str(president) + "]"
            field = json_obj["question"]
            president_fields.append(aa + "-" + field)

    return president_fields


def build_doc_term_mat(documents):
    """주어진 문서 집합으로부터 문서-단어 행렬을 생성하여 돌려준다."""
    
    vectorizer = TfidfVectorizer(tokenizer=str.split)
    doc_term_mat = vectorizer.fit_transform(documents)

    return doc_term_mat


def get_hier_clusters(doc_term_mat):
    """주어진 문서-단어 행렬에 대하여 계층적 군집화를 수행하여 결과를 돌려준다."""
    
    clusters = linkage(doc_term_mat.toarray(), "ward")

    return clusters


def plot_linkage(output_file_name, clusters, president_fields):
    """덴드로그램을 주어진 이름의 출력 파일에 출력한다."""
    
    set_fonts()
    plt.figure(figsize=(40, 80))
    dendrogram(clusters, orientation="right", labels=president_fields,
               leaf_font_size=5)
    plt.savefig(output_file_name, dpi=200)
    # 덴드로그램을 화면에 직접 표시라면 아래의 주석을 해제한다.
    # plt.show()
    plt.close()
    
    
def set_fonts():
    """플랫폼에 따라 출력에 사용할 글꼴을 지정한다."""
    
    if sys.platform.startswith("win"):
        matplotlib.rc("font", family="Malgun Gothic")
    elif sys.platform.startswith("darwin"):
        matplotlib.rc("font", family="AppleGothic")

    
def main():
    """소요리문답 자료를 계층적 방법으로 군집화한다."""
    
    input_file_name = "data/catechism/catechism.ma.txt"
    output_file_name = "data/catechism/nmh_catechism.dendro.png"
    
    documents = read_documents(input_file_name)
    president_fields = read_president_fields(input_file_name)
    doc_term_mat = build_doc_term_mat(documents)
# 십계명 서문 무엇 십계명 서문 이러 말 곧 나 너희 하나님 너 종 애굽 땅 나오 자 하
# 십계명 서문 우리 교훈 무엇 십계명 서문 우리 교훈 하나님 주도 우리 하나님 되 우리 구속자 되 고로 우리 마땅히 그 계명 지키 하 하
# 제일 계명 무엇 제일 계명 나 신 위하 마르 하
# 제일 계명 무엇 제일 계명 우리 하나님 유일 참 신이 우리 하나님 되 알 승인 그대로 경배 영화 하 하
# 제일 계명 금하 무엇 제 일 계명 금하 참 신 하나님 알 우리 하나님 경배 영화 하 그 드리 합당 경배 영화 이 드리
# 제 일 계명 나 라 말씀 우리 특별히 교훈 무엇 제 일 계명 나 말씀 우리 특별히 교훈 만물 보 하나님 신 위하 죄 내리 보 분하 여기
# 제 이 계명 무엇 제 이 계명 우상 만들 위 하늘 있 아래 땅 있 땅 아래 물속 있 형상 만들 절 섬기 마르
# 제 이 계명 무엇 제 이 계명 하나님 말씀 정하 종교 예배 규례 받 순종 깨끗 완전 지키 하
# 제 이 계명 금하 무엇 제 이 계명 금하 우상 하나님 경배 하나님 말씀 정하 방법 경배
# 제 이 계명 지키 이유 무엇 제 이 계명 지키 이유 하나님 우리 주재 되 우리 소유자 되 홀로 자기 경배 바라
# 제 삼 계명 무엇 제 삼 계명 너희 하나님 여호와 이름 망령 일컫 마르 여호와 이름 망령 일컫 죄 없 하
# 제 삼 계명 무엇 제 삼 계명 하나님 이름 칭호 속성 규례 말씀 행사 거룩 존경 마음 사용 하
# 제 삼 계명 금하 무엇 제 삼 계명 금하 무엇 하나님 자기 나타내 훼방 악용
# 제 삼 계명 지키 이유 무엇 제 삼 계명 지키 이유 계명 범하 비록 사람 형벌 피하 우리 하나님 저희 하여금 의롭 심판 피하 하
# 제 사 계명 무엇 제 사 계명 안식일 기억 거룩 날로 지키 엿새 동안 일 힘쓰 하 치 너희 하나님 여호와 안식일 너 자녀 노비 육 축 문안 유 객 일 마르
# 제 사 계명 무엇 제 사 계명 하나님 말씀 명하 절기 그 앞 지키 특별히 치 하루 종일토록 그 루 룩 안식일 삼 하
# 하나님 치 날 안식일 명하 세상 시작 그리스도의 부활 하나님 이레 일곱째 날 안식일 명하 후 세상 끝 날 이르 이레 첫날 명하 곧 그리스도인 안식일
# 어떻 하 안식일 거룩 하 안식일 거룩 하 그날 종일 거룩 쉬 하 날 합당 세상 일 오락 그치 시간 공사 예배 바치 사용 사세 부득이 일 자선 사업 사용
# 제 사 계명 금하 무엇 제 사 계명 금하 의무 이행 혹 주의 나태 날 더럽 하 죄 일 행하 세상 일 오락 대하 불필요 생각 말 행동 하
# 제 사 계명 지키 이유 무엇 제 사 계명 지키 이유 하나님 우리 행하 일 위하 여섯 날 허락 치 자기 특별히 주장 이 되 하심 자기 친히 모범 보이 안식일 축복
# 제 오 계명 무엇 제 오 계명 부모 공경
# 제 오 계명 무엇 제 오 계명 사람 속 지위 인륜 관계 곧 상하 평등 따르 높이 높이 행하 일 하
# %% [markdown]
# ## 비계층적 군집화
# 비계층적 군집화(non-hierarchicnal clustering)는 자료 항목들을 주어진 갯수의 군집들로 분할(partition)하는 군집화 방법으로 처리 속도가 빨라 많은 분야에서 사용하고 있다. 가장 널리 사용되는 기법은 K-평균(k-means)이다.
#
# K-평균 기법은 같은 군집에 속한 자료 항목들은 서로 거리가 "가깝다"라는 간단한 가정에서 시작한다. 각각의 군집에는 **중심(centroid)**을 하나씩 설정하고 이로부터 각각의 자료와의 거리는 비용(cost)으로 정의한다. 결국 K-평균은 이와 같이 정의한 비용을 최소화하는 군집을 찾는 알고리즘이다.
#
# 앞서 계층적 군집화의 대상이 된 대통령 연설문 집합을 대상으로 K-평균 군집화 실험을 해보자.

# %%
# 소요리문답 자료를 KMeans 군집화

import ujson
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import sys
import matplotlib
import matplotlib.pyplot as plt
import collections
import pickle

FEATURE_POSES = ["NNG", "NNP", "NR", "NP", "XR", "MAG", "VA", "VV"]
MA_KEYS = ["question_ma", "answer_ma"]

NUM_CLUSTERS = 11


def read_documents(input_file_name):
    """주어진 이름의 파일에서 문서들을 읽어서 돌려준다."""
    
    documents = []
    qna_documents = []

    with open(input_file_name, "r", encoding="utf-8") as input_file:
        for line in input_file:
            morphs = []
            json_obj = ujson.loads(line)

            for ma_key in MA_KEYS:
                for morph_lex, morph_cat in json_obj[ma_key]:
                    if morph_cat not in FEATURE_POSES:
                        continue
                        
                    morphs.append(morph_lex)

            document = " ".join(morphs)
            #print(document)
            documents.append(document)
            #print("문답[{}] 키워드 추출대상 단어[{}]".format(json_obj["no"], morphs))
            qna_document = json_obj["question"]
            qna_documents.append(qna_document)
            
    return documents, qna_documents


def build_doc_term_mat(documents):
    """주어진 문서 집합으로부터 문서-단어 행렬을 생성하여 돌려준다."""
    
    vectorizer = TfidfVectorizer(tokenizer=str.split)
    doc_term_mat = vectorizer.fit_transform(documents)
    words = vectorizer.get_feature_names()
    
    #store the vectorizer(TfidfVectorizer(tokenizer=str.split))
    with open("catechism_vectorizer.pkl", 'wb') as handle:
        pickle.dump(vectorizer, handle)
        
    return vectorizer, doc_term_mat, words


def get_flat_clusters(doc_term_mat, kmeans_pkl_filename):
    """주어진 문서-단어 행렬에 대하여 비계층적 군집화를 수행하여 모델을 돌려준다."""
    
    km = KMeans(n_clusters=NUM_CLUSTERS, init="k-means++", verbose=1)
    km.fit(doc_term_mat)
    
    # Open the file to save as pkl file
    kmeans_model_pkl = open(kmeans_pkl_filename, 'wb')
    pickle.dump(km, kmeans_model_pkl)
    # Close the pickle instances
    kmeans_model_pkl.close()
    
    return km


def print_centroid_words(model, words, qna_documents):
    """주어진 모델과 단어들을 이용하여 군집별 중심 단어를 출력한다."""
    
    print("군집별 중심 단어")
    print()

    ordered_centroids = model.cluster_centers_.argsort()[:, ::-1]
    #print("ordered_centroids=[{}]".format(ordered_centroids))
    clusters = collections.defaultdict(list)
    for i, label in enumerate(model.labels_):
        #print("문장번호=[{}],클러스터번호=[{}]".format(i,label))
        clusters[label].append(i)
    


    for cluster_num in range(NUM_CLUSTERS):
        center_word_nums = [word_num for word_num 
                            in ordered_centroids[cluster_num, :20]]
        #print("center_word_nums=[{}]".format(center_word_nums))
        center_words = [words[word_num] for word_num in center_word_nums]
        print("군집 키워드 {}: {}".format(cluster_num, ", ".join(center_words)))
        print()
        for i,sentence in enumerate(clusters[cluster_num]):
            print("\t문장  {} :문답번호=[{}]{}".format(i, sentence+1, qna_documents[sentence]))
        print("="*100)

def set_font():
    """차트의 글꼴을 설정한다."""
    
    if sys.platform in ["win32", "win64"]:
        font_name = "malgun gothic"
    elif sys.platform == "darwin":
        font_name = "AppleGothic"
        
    matplotlib.rc("font", family=font_name)

def elbow(X):
    sse = []
    for i in range(1,11):
        km = KMeans(n_clusters=i, init='k-means++', random_state=0)
        km.fit(X)
        sse.append(km.inertia_)
    
    set_font()    
    plt.plot(range(1,11), sse, marker='o')
    plt.xlabel('클러스터 개수')
    plt.ylabel('SSE')
    plt.show()
    
def get_prediction_by_kmeans_model(sentence, vectorizer, kmeans_pkl_filename):
    """학습된 K-Means모델로부터 예측을 수행한다."""
    print("\n")
    print("Prediction")
    
    # Loading the saved KMeans clustering model pickle
    kmeans_model_pkl = open(kmeans_pkl_filename, 'rb')
    kmeans_model_model = pickle.load(kmeans_model_pkl)
    print("Loaded kmeans model :: {}".format(kmeans_model_model))

    Y = vectorizer.transform(sentence)
    prediction = kmeans_model_model.predict(Y)
    print(prediction)

def main():
    """소요리문답 자료를 비계층적 방법으로 군집화한다."""
    
    input_file_name = "data/catechism/catechism.ma.txt"
    clusters = collections.defaultdict(list)
    # Dump the trained KMeans clustering with Pickle
    kmeans_pkl_filename = 'kmeans_pkle_clustering_20171129.pkl'
    sentence = ["사람 의 제일 되는 목적 이 무엇 이 ㄴ가 ?"]
    #sentence = ["하나님 은 어떤 분 이 시 ㄴ가 ?"]


    documents, qna_documents = read_documents(input_file_name)
    vectorizer, doc_term_mat, words = build_doc_term_mat(documents)
    model = get_flat_clusters(doc_term_mat, kmeans_pkl_filename)
    print_centroid_words(model, words, qna_documents)
    elbow(doc_term_mat)
    get_prediction_by_kmeans_model(sentence, vectorizer, kmeans_pkl_filename)
        

# 실행
main()
# Out:
# Initialization complete
# Iteration 0, inertia 148.75959117290546
# Iteration 1, inertia 81.31636984293782
# Iteration 2, inertia 80.83416759125383
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 147.48211889042477
# Iteration 1, inertia 80.94277998966443
# Converged at iteration 1: strict convergence.
# Initialization complete
# Iteration 0, inertia 146.29136187906516
# Iteration 1, inertia 80.56304493320653
# Iteration 2, inertia 80.41568213005014
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 147.0272302835683
# Iteration 1, inertia 81.3149734062184
# Iteration 2, inertia 81.12123892620914
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 146.1158171151988
# Iteration 1, inertia 81.04494133563375
# Iteration 2, inertia 80.599318248814
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 147.1720670145375
# Iteration 1, inertia 82.09606648392013
# Iteration 2, inertia 81.94101721014698
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 145.39107537141038
# Iteration 1, inertia 81.04647150741695
# Iteration 2, inertia 80.78235901115295
# Iteration 3, inertia 80.48322149476022
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 148.86190334181782
# Iteration 1, inertia 81.7525438690471
# Iteration 2, inertia 81.5904062797283
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 143.41166515431055
# Iteration 1, inertia 80.84298602657918
# Iteration 2, inertia 80.68402724081088
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 149.18795755535663
# Iteration 1, inertia 81.86143181418524
# Iteration 2, inertia 81.42053826502294
# Iteration 3, inertia 81.2768516331117
# Iteration 4, inertia 81.14007087711556
# Converged at iteration 4: strict convergence.
# 군집별 중심 단어
#
# 군집 키워드 0: 우리, 그리스도, 성령, 구속, 사신, 하, 효력, 있, 적용, 신격, 삼위, 성자, 성부, 세례, 하나님의, 참여, 하나님, 아들, 어떻, 의롭
#
# 	문장  0 :문답번호=[6]하나님의 신격에 몇 위가 계신가?
# 	문장  1 :문답번호=[22]그리스도께서 하나님의 아들로서 어떻게 사람이 되셨는가?
# 	문장  2 :문답번호=[29]우리로 어떻게 그리스도의 사신 구속에 참여하게 하시는가?
# 	문장  3 :문답번호=[30]성령께서 그리스도의 사신 구속을 우리에게 어떻게 적용하셨는가?
# 	문장  4 :문답번호=[31]효력있는 부름심이 무엇인가?
# 	문장  5 :문답번호=[33]의롭다 하심은 무엇인가?
# 	문장  6 :문답번호=[94]세례가 무엇인가?
# ====================================================================================================
# 군집 키워드 1: 제, 계명, 금하, 이웃, 칠, 무엇, 팔, 육, 구, 마르, 하, 십, 삼, 생명, 우리, 해, 증진, 있, 보존, 남
#
# 	문장  0 :문답번호=[49]제 이 계명이 무엇인가?
# 	문장  1 :문답번호=[53]제 삼 계명이 무엇인가?
# 	문장  2 :문답번호=[54]제 삼 계명이 명하는 것은 무엇인가?
# 	문장  3 :문답번호=[55]제 삼 계명이 금하는 것은 무엇인가?
# 	문장  4 :문답번호=[67]제 육 계명이 무엇인가?
# 	문장  5 :문답번호=[68]제 육 계명이 명하는 것은 무엇인가?
# 	문장  6 :문답번호=[69]제 육 계명이 금하는 것은 무엇인가?
# 	문장  7 :문답번호=[70]제 칠 계명이 무엇인가?
# 	문장  8 :문답번호=[71]제 칠 계명이 명하는 것은 무엇인가?
# 	문장  9 :문답번호=[72]제 칠 계명이 금하는 것은 무엇인가?
# 	문장  10 :문답번호=[73]제 팔 계명이 무엇인가?
# 	문장  11 :문답번호=[74]제 팔 계명이 명하는 것은 무엇인가?
# 	문장  12 :문답번호=[75]제 팔 계명이 금하는 것은 무엇인가?
# 	문장  13 :문답번호=[76]제 구 계명이 무엇인가?
# 	문장  14 :문답번호=[77]제 구 계명이 명하는 것은 무엇인가?
# 	문장  15 :문답번호=[78]제 구 계명이 금하는 것은 무엇인가?
# 	문장  16 :문답번호=[79]제 십 계명이 무엇인가?
# 	문장  17 :문답번호=[80]제 십 계명이 명하는 것은 무엇인가?
# 	문장  18 :문답번호=[81]제 십 계명에 금하는 것이 무엇인가?
# ====================================================================================================
# 군집 키워드 2: 창조, 죄, 지위, 타락, 받, 보, 비참, 하나님, 시조, 인종, 하, 예정, 이루, 범하, 사람, 이르, 보응, 무엇, 섭리, 어기
#
# 	문장  0 :문답번호=[8]하나님께서 그 예정을 어떻게 이루시는가?
# 	문장  1 :문답번호=[9]창조하신 일이 무엇인가?
# 	문장  2 :문답번호=[12]사람이 창조함을 받은 본 지위에 있을 때에 하나님께서 저를 향하여 섭리하시는 중 에 무슨 특별한 작정을 하셨는가?
# 	문장  3 :문답번호=[13]우리 시조가 창조함을 받은 본 지위에 그대로 있었는가?
# 	문장  4 :문답번호=[14]죄가 무엇인가?
# 	문장  5 :문답번호=[15]우리 시조가 창조함을 받은 본 지위에서 타락하게 된 죄가 무엇인가?
# 	문장  6 :문답번호=[17]이 타락이 인종으로 하여금 어떠한 지위에 이르게 하였는가?
# 	문장  7 :문답번호=[18]사람이 타락한 지위에서 죄되는 것이 무엇인가?
# 	문장  8 :문답번호=[19]사람이 타락한 지위에서 비참한 것이 무엇인가?
# 	문장  9 :문답번호=[20]하나님께서 모든 인종을 죄와 비참한 지위에서 멸망하게 버려두셨는가?
# 	문장  10 :문답번호=[84]범한 죄마다 마땅히 받을 보응이 무엇인가?
# ====================================================================================================
# 군집 키워드 3: 제일, 하나님, 영화, 경배, 계명, 우리, 하, 되, 교훈, 금하, 성경, 무엇, 이, 즐거워하, 목적, 사람, 그, 신, 양자, 요긴
#
# 	문장  0 :문답번호=[1]사람의 제일 되는 목적이 무엇인가?
# 	문장  1 :문답번호=[2]하나님께서 무슨 규칙을 우리에게 주시어 어떻게 자기를 영화롭게 하고 즐거워할 것을 지시하셨는가?
# 	문장  2 :문답번호=[3]성경이 제일 요긴하게 교훈하는 것이 무엇인가?
# 	문장  3 :문답번호=[34]양자로 삼는 것이 무엇인가?
# 	문장  4 :문답번호=[44]십계명의 서문이 우리에게 교훈하는 것이 무엇인가?
# 	문장  5 :문답번호=[45]제일 계명이 무엇인가?
# 	문장  6 :문답번호=[46]제일 계명이 명하는 것은 무엇인가?
# 	문장  7 :문답번호=[47]제일 계명이 금하는 것은 무엇인가?
# 	문장  8 :문답번호=[51]제 이 계명이 금하는 것이 무엇인가?
# ====================================================================================================
# 군집 키워드 4: 직분, 행하, 그리스도, 우리, 선지자, 왕, 제사장, 베풀, 구속자, 자기, 어떻, 세례, 하, 복종, 높, 낮, 고백, 입교, 다스리, 이기
#
# 	문장  0 :문답번호=[23]그리스도께서 우리의 구속자로 무슨 직분을 행하시는가?
# 	문장  1 :문답번호=[24]그리스도께서 어떻게 선지자의 직분을 행하시는가?
# 	문장  2 :문답번호=[25]그리스도께서 어떻게 제사장의 직분을 행하시는가?
# 	문장  3 :문답번호=[26]그리스도께서 어떻게 왕의 직분을 행하시는가?
# 	문장  4 :문답번호=[95]세례는 어떠한 사람에게 베푸는가?
# ====================================================================================================
# 군집 키워드 5: 하나님, 사람, 거룩, 살, 본분, 참되, 공의, 요구, 하, 선택, 계시, 구속자, 능히, 대하, 영원, 사용, 무한, 무궁, 불변, 인자
#
# 	문장  0 :문답번호=[4]하나님은 어떤 분이신가?
# 	문장  1 :문답번호=[5]하나님 한분밖에 또 다른 하나님이 계신가?
# 	문장  2 :문답번호=[10]하나님께서 사람을 어떻게 지으셨는가?
# 	문장  3 :문답번호=[21]하나님의 선택하신 자의 구속자가 누구신가?
# 	문장  4 :문답번호=[35]거룩하게 하신 것이 무엇인가?
# 	문장  5 :문답번호=[39]하나님께서 사람에게 요구하시는 본분이 무엇인가?
# 	문장  6 :문답번호=[60]어떻게 하여야 안식일을 거룩하게 하겠는가?
# ====================================================================================================
# 군집 키워드 6: 성례, 유익, 구원, 그리스도, 얻, 우리, 되, 기도, 받, 효력, 그, 하나님, 성찬, 말씀, 하심, 나타내, 예수, 신약, 보통, 방법
#
# 	문장  0 :문답번호=[16]모든 인종은 아담의 첫 범죄 중에 타락하였는가?
# 	문장  1 :문답번호=[32]효력 있는 부르심을 받은 자들은금생에서 무슨 유익을 얻는가?
# 	문장  2 :문답번호=[36]금생에서 의롭다 하심과 양자로 삼으신 것과 거룩하게 하심에서 함께 받는 유익과 여기서 나오는 유익이 무엇인가?
# 	문장  3 :문답번호=[85]우리가 죄를 인하여 하나님께 받을 진노의 저주를 피하게 하려고 하나님이 우리에게 요구하시는 것이 무엇인가?
# 	문장  4 :문답번호=[86]예수 그리스도를 믿는 것은 무엇인가?
# 	문장  5 :문답번호=[88]그리스도께서 우리에게 구원의 유익을 전하시려고 나타내시는 보통 방법이 무엇인가?
# 	문장  6 :문답번호=[89]하나님의 말씀이 어떻게 효력이 되어 구원을 얻게 하는가?
# 	문장  7 :문답번호=[90]하나님의 말씀을 어떻게 읽고 들어야 효력이 되어 구원을 얻는 방도가 되는가?
# 	문장  8 :문답번호=[91]성례가 어떻게 효력이 되어 구원을 얻게 하는 방도가 되는가?
# 	문장  9 :문답번호=[92]성례가 무엇인가?
# 	문장  10 :문답번호=[93]신약의 성례가 무엇인가?
# 	문장  11 :문답번호=[96]주의 성찬이 무엇인가?
# 	문장  12 :문답번호=[98]기도가 무엇인가?
# 	문장  13 :문답번호=[99]하나님께서 우리의 기도를 지시하시려고 주신 법칙이 무엇인가?
# ====================================================================================================
# 군집 키워드 7: 기도, 주기도문, 우리, 구하, 때, 나라, 하, 영광, 함, 곧, 아버지, 그리스도, 첫, 하나님, 받, 신자, 사, 하여금, 마지막, 하늘
#
# 	문장  0 :문답번호=[27]그리스도의 낮아지심이 어떠한가?
# 	문장  1 :문답번호=[28]그리스도의 높아지심이 어떠한가?
# 	문장  2 :문답번호=[37]신자가 죽을 때에 그리스도에게서 무슨 유익을 받는가?
# 	문장  3 :문답번호=[38]신자가 부활할 때에는 그리스도에게서 무슨 유익을 받는가?
# 	문장  4 :문답번호=[100]주기도문의 첫 말씀이 우리에게 무엇을 교훈하는가?
# 	문장  5 :문답번호=[101]첫 기도에 우리가 무엇을 구하는가?
# 	문장  6 :문답번호=[102]둘째 기도에 우리가 무엇을 구하는가?
# 	문장  7 :문답번호=[103]주기도문의 셋째 기도에 우리가 무엇을 구하는가?
# 	문장  8 :문답번호=[104]주기도문의 넷째 기도에 우리가 무엇을 구하는가?
# 	문장  9 :문답번호=[105]주기도문의 다섯째 기도에 우리가 무엇을 구하는가?
# 	문장  10 :문답번호=[106]주기도문의 여섯째 기도에 우리가 무엇을 구하는가?
# 	문장  11 :문답번호=[107]주기도문의 마지막 구절이 우리에게 무엇을 교훈하는가?
# ====================================================================================================
# 군집 키워드 8: 사, 일, 제, 계명, 안식일, 지키, 하나님, 자기, 치, 이유, 명하, 특별히, 날, 무엇, 되, 보이, 이, 예정, 섭리, 위하
#
# 	문장  0 :문답번호=[7]하나님의 예정이 무엇인가?
# 	문장  1 :문답번호=[11]하나님의 섭리하시는 일이 무엇인가?
# 	문장  2 :문답번호=[40]하나님께서 자기에게 복종할 규칙으로 사람에게 처음 나타내 보이신 것이 무엇인가?
# 	문장  3 :문답번호=[48]제 일 계명중에 「나 외에」라 한 말씀이 우리에게 특별히 교훈하는 것이 무엇인가?
# 	문장  4 :문답번호=[52]제 이 계명이 「지키라」한 이유가 무엇인가?
# 	문장  5 :문답번호=[57]제 사 계명이 무엇인가?
# 	문장  6 :문답번호=[58]제 사 계명이 명하는 것은 무엇인가?
# 	문장  7 :문답번호=[59]하나님께서 칠 일 중에 어느 날을 안식일로 명하셨는가?
# 	문장  8 :문답번호=[61]제 사 계명이 금하는 것은 무엇인가?
# 	문장  9 :문답번호=[62]제 사 계명이 「지키라」한 이유가 무엇인가?
# ====================================================================================================
# 군집 키워드 9: 다, 십계명, 죄, 악하, 간략히, 포함, 서문, 도덕, 회개, 사랑, 법칙, 참여, 합당, 강령, 같이, 자기, 힘, 하나님, 주님, 생명
#
# 	문장  0 :문답번호=[41]이 도덕의 법칙이 어디에 간략히 포함되었는가?
# 	문장  1 :문답번호=[42]십계명의 대강령이 무엇인가?
# 	문장  2 :문답번호=[43]십계명의 서문이 무엇인가?
# 	문장  3 :문답번호=[83]법을 범한 모든 죄가 다 같이 악한가?
# 	문장  4 :문답번호=[87]생명에 이르는 회개가 무엇인가?
# 	문장  5 :문답번호=[97]주의 성찬에 합당하게 참여하려면 어떻게 하여야 하는가?
# ====================================================================================================
# 군집 키워드 10: 계명, 오, 제, 지키, 사람, 이유, 높이, 따르, 관계, 인륜, 무엇, 속, 완전히, 하, 피하, 부모, 하나님, 범하, 공경, 행하
#
# 	문장  0 :문답번호=[50]제 이 계명이 명하는 것이 무엇인가?
# 	문장  1 :문답번호=[56]제 삼 계명이 「지키라」한 이유가 무엇인가?
# 	문장  2 :문답번호=[63]제 오 계명이 무엇인가?
# 	문장  3 :문답번호=[64]제 오 계명이 명하는 것은 무엇인가?
# 	문장  4 :문답번호=[65]제 오 계명이 금하는 것이 무엇인가?
# 	문장  5 :문답번호=[66]제 오 계명이 「지키라」한 이유가 무엇인가?
# 	문장  6 :문답번호=[82]아무 사람이나 능히 하나님의 계명을 완전히 지킬 수 있는가?
# ====================================================================================================
# Prediction
# Loaded kmeans model :: KMeans(n_clusters=11, verbose=1)
# [3]
